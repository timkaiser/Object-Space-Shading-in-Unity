# %% [markdown]
# # Second Test Evaluation

# %%
#imports
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
#read data
labels = ['tile size','screen size','cam id 1','tiles cam 1','cam id 2','tiles cam 2', 'common tiles']
data = pd.read_csv("SecondTest\SecondTest.csv",names =  labels)

# %%
#add percentage data
data['% cam 1'] = data['common tiles']/data['tiles cam 1']
data['% cam 2'] = data['common tiles']/data['tiles cam 2']

# %%
#group data
groupedData = data[['tile size','screen size','tiles cam 1','tiles cam 2', 'common tiles','% cam 1','% cam 2']].groupby(['tile size','screen size']).mean()

# %%
groupedData
# Out:
#                        tiles cam 1  tiles cam 2  common tiles   % cam 1  \
# tile size screen size
# 8          1024x768        26494.8      20297.2        1434.4  0.053818
#            1920x1080       42611.2      34029.6        2638.5  0.062126
#            3840x2160       81199.3      58828.3        5914.8  0.072645
#            800x600         18974.3      14682.1        1059.7  0.055309
# 16         1024x768        10845.4       7948.2         938.1  0.086328
#            1920x1080       16558.7      12790.9        1462.6  0.088714
#            3840x2160       29642.9      20846.7        2682.8  0.090388
#            800x600          8130.9       6045.9         773.5  0.094648
# 32         1024x768         5085.9       3702.5         751.1  0.147848
#            1920x1080        7413.4       5731.8        1070.2  0.145077
#            3840x2160       12485.3       8734.7        1640.4  0.131543
#            800x600          3934.8       2928.4         656.6  0.166967
# 64         1024x768         2547.7       1917.9         607.5  0.239687
#            1920x1080        3617.9       2892.1         868.5  0.241501
#            3840x2160        5872.8       4231.6        1255.6  0.214800
#            800x600          1970.2       1524.2         514.9  0.262840
#
#                         % cam 2
# tile size screen size
# 8          1024x768    0.063592
#            1920x1080   0.077648
#            3840x2160   0.102726
#            800x600     0.062407
# 16         1024x768    0.103657
#            1920x1080   0.110016
#            3840x2160   0.125080
#            800x600     0.110808
# 32         1024x768    0.186184
#            1920x1080   0.179620
#            3840x2160   0.179288
#            800x600     0.205895
# 64         1024x768    0.308836
#            1920x1080   0.296112
#            3840x2160   0.290011
#            800x600     0.329143
